# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('../data/co-est2015-alldata-utf8.csv')
df2 = pd.read_csv('../data/2015_Gaz_counties_national-utf8.csv')

# %%
df1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df2.head()
# Out:
#   USPS  GEOID  ANSICODE            NAME       ALAND      AWATER  ALAND_SQMI  \
# 0   AL   1001    161526  Autauga County  1539589643    25769317     594.439
# 1   AL   1003    161527  Baldwin County  4117584013  1133129224    1589.808
# 2   AL   1005    161528  Barbour County  2291820706    50864677     884.877
# 3   AL   1007    161529     Bibb County  1612481559     9287974     622.583
# 4   AL   1009    161530   Blount County  1670041875    15077458     644.807
#
#    AWATER_SQMI   INTPTLAT  INTPTLONG
# 0        9.950  32.532237 -86.646440
# 1      437.504  30.659218 -87.746067
# 2       19.639  31.870253 -85.405104
# 3        3.586  33.015893 -87.127148
# 4        5.821  33.977358 -86.566440

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 100 columns):
# SUMLEV                   3193 non-null int64
# REGION                   3193 non-null int64
# DIVISION                 3193 non-null int64
# STATE                    3193 non-null int64
# COUNTY                   3193 non-null int64
# STNAME                   3193 non-null object
# CTYNAME                  3193 non-null object
# CENSUS2010POP            3193 non-null int64
# ESTIMATESBASE2010        3193 non-null int64
# POPESTIMATE2010          3193 non-null int64
# POPESTIMATE2011          3193 non-null int64
# POPESTIMATE2012          3193 non-null int64
# POPESTIMATE2013          3193 non-null int64
# POPESTIMATE2014          3193 non-null int64
# POPESTIMATE2015          3193 non-null int64
# NPOPCHG_2010             3193 non-null int64
# NPOPCHG_2011             3193 non-null int64
# NPOPCHG_2012             3193 non-null int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 10 columns):
# USPS           3220 non-null object
# GEOID          3220 non-null int64
# ANSICODE       3220 non-null int64
# NAME           3220 non-null object
# ALAND          3220 non-null int64
# AWATER         3220 non-null int64
# ALAND_SQMI     3220 non-null float64
# AWATER_SQMI    3220 non-null float64
# INTPTLAT       3220 non-null float64
# INTPTLONG      3220 non-null float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 251.6+ KB

# %%
df2['ALAND_SQMI'].hist();

# %%
print(df2['ALAND_SQMI'].max(), df2['ALAND_SQMI'].min(), df2['ALAND_SQMI'].mean())
# Out:
# 145492.713 2.051 1097.9796552795024

# %%
df2.iloc[np.where(df2["ALAND_SQMI"] == df2['ALAND_SQMI'].max())]
# Out:
#    USPS  GEOID  ANSICODE                       NAME         ALAND      AWATER  \
# 95   AK   2290   1419987  Yukon-Koyukuk Census Area  376824381721  5954833881
#
#     ALAND_SQMI  AWATER_SQMI   INTPTLAT   INTPTLONG
# 95  145492.713     2299.174  65.375716 -151.577878

# %%
df2.sort_values(['ALAND_SQMI'], axis=0, ascending=False)
# Out:
#      USPS  GEOID  ANSICODE                             NAME         ALAND  \
# 95     AK   2290   1419987        Yukon-Koyukuk Census Area  376824381721
# 85     AK   2185   1419978              North Slope Borough  230092740514
# 70     AK   2050   1419966               Bethel Census Area  105075885504
# 86     AK   2188   1419979         Northwest Arctic Borough   92295122743
# 92     AK   2261   1419984       Valdez-Cordova Census Area   88676741086
# 91     AK   2240   1419983  Southeast Fairbanks Census Area   64147802443
# 83     AK   2170   1419976        Matanuska-Susitna Borough   63734631763
# 82     AK   2164   1419975       Lake and Peninsula Borough   60735993529
# 84     AK   2180   1419977                 Nome Census Area   59473768672
# 221    CA   6071    277300            San Bernardino County   51947553553
# 98     AZ   4005     25443                  Coconino County   48222080889
# 73     AK   2070   1419968           Dillingham Census Area   48093448272
# ...

# %%
df2['log_ALAND_SQMI'] = np.log(df2['ALAND_SQMI'])
df2['log_ALAND_SQMI'].hist();

# %%
counties_pop = set(df1['CTYNAME'])
counties_area = set(df2['NAME'])

# %%
dif = counties_pop - counties_area
len(dif)
# Out:
# 50

# %%
# next step: remove states from counties_pop, unify datframes and start making nice dataplots
df1.drop(df[df.SUMLEV == 40].index, inplace=True)
counties_pop = set(df1['CTYNAME'])
dif = counties_pop - counties_area
len(dif)
# Out:
# 50

# %%
df1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...
